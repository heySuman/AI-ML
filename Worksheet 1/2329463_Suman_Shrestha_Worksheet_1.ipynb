# %% [markdown]
# # **1. Excercise One**

# %%
# Importing required library
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Read and display the image.

# %%
# Read the image using the Pillow library and display it.

image_colored = Image.open("/content/drive/MyDrive/AI ML/Worksheet 1/Lenna_(test_image).png")
display(image_colored)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# ## 2. Display only the top left corner of 100x100 pixels.

# %%
# convert the colored_image to the numpy array
image_colored_arr = np.array(image_colored)

# Information of the shape and size
print("Shape of the colored image is : ", image_colored_arr.shape)
print("Size of the colored image is : ", image_colored_arr.size)
# Out:
# Shape of the colored image is :  (512, 512, 3)
# Size of the colored image is :  786432

# %%
# Displaying only the top left corner of 100 X 100 pixels

top_100_pixels = image_colored_arr[0:100, 0:100]
display(top_100_pixels)
# Out:
# array([[[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        ...,
#
#        [[177,  64,  79],
#         [177,  64,  79],
#         [163,  58,  74],
#         ...,
#         [177,  65,  79],
#         [172,  68,  79],
#         [172,  75,  83]],
#
#        [[169,  63,  79],
#         [169,  63,  79],
#         [159,  53,  74],
#         ...,
#         [175,  70,  85],
#         [178,  72,  84],
#         [178,  63,  75]],
#
#        [[166,  55,  74],
#         [166,  55,  74],
#         [154,  51,  71],
# ...

# %% [markdown]
# ## 3. Show the three color channels (R, G, B).

# %%
red_channel = image_colored_arr[:,:,0]
green_channel = image_colored_arr[:,:,1]
blue_channel = image_colored_arr[:,:,2]

print("Red Channel data\n",red_channel)
print("Green Channel data\n",green_channel)
print("Blue Channel data\n",blue_channel)
# Out:
# Red Channel data
#  [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]
# Green Channel data
#  [[137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  ...
#  [ 18  18  27 ...  73  68  62]
#  [ 22  22  32 ...  70  71  74]
#  [ 22  22  32 ...  70  71  74]]
# Blue Channel data
#  [[125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  ...
#  [ 60  60  58 ...  84  76  79]
#  [ 57  57  62 ...  79  81  81]
#  [ 57  57  62 ...  79  81  81]]

# %%
# showing three color channels (RGB)
display(red_channel,green_channel,blue_channel)
# Out:
# array([[226, 226, 223, ..., 230, 221, 200],
#        [226, 226, 223, ..., 230, 221, 200],
#        [226, 226, 223, ..., 230, 221, 200],
#        ...,
#        [ 84,  84,  92, ..., 173, 172, 177],
#        [ 82,  82,  96, ..., 179, 181, 185],
#        [ 82,  82,  96, ..., 179, 181, 185]], dtype=uint8)
# array([[137, 137, 137, ..., 148, 130,  99],
#        [137, 137, 137, ..., 148, 130,  99],
#        [137, 137, 137, ..., 148, 130,  99],
#        ...,
#        [ 18,  18,  27, ...,  73,  68,  62],
#        [ 22,  22,  32, ...,  70,  71,  74],
#        [ 22,  22,  32, ...,  70,  71,  74]], dtype=uint8)
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)

# %% [markdown]
# ## 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# > Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a light gray color), and then display the modified image.

# %%
# change the top left 100 pixels to have the 210 value
image_colored_arr[:100,:100] = 210

display(image_colored_arr)
# Out:
# array([[[210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        [[210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        [[210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        ...,
#
#        [[ 84,  18,  60],
#         [ 84,  18,  60],
#         [ 92,  27,  58],
#         ...,
#         [173,  73,  84],
#         [172,  68,  76],
#         [177,  62,  79]],
#
#        [[ 82,  22,  57],
#         [ 82,  22,  57],
#         [ 96,  32,  62],
#         ...,
#         [179,  70,  79],
#         [181,  71,  81],
#         [185,  74,  81]],
#
#        [[ 82,  22,  57],
#         [ 82,  22,  57],
#         [ 96,  32,  62],
# ...

# %% [markdown]
# # **2. Exercise Two:**

# %% [markdown]
# ## 1. Load and display a grayscale image.

# %%
gray_image = Image.open('/content/drive/MyDrive/AI ML/Worksheet 1/cameraman.png')

# %%
# display the loaded image with matplotlib
plt.title("Grayscale image")
plt.imshow(gray_image)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## 2. Extract and display the middle section of the image (150 pixels).

# %%
# Convert the image to the numpy array
gray_image_arr = np.array(gray_image)

# Extract the height and width of the image
h,w = gray_image_arr.shape

middle_row = gray_image_arr[(h//2 - 75): ((h//2) + 75),(w//2-75) : ((w//2) + 75) ]

plt.imshow(middle_row)
plt.axis('off')
# Out:
# (-0.5, 149.5, 149.5, -0.5)

# %% [markdown]
# ## 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).

# %%
# Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).

binary_img = gray_image.point(lambda x: 255 if x > 100 else 0)
plt.imshow(binary_img)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## 4. Rotate the image 90 degrees clockwise and display the result.
#
#
# >  Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating the image array.
# > Display the rotated image using matplotlib.

# %%
# roatate to clockwise
plt.imshow(gray_image.rotate(-90))
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# rotate the image by anti-clockwise
plt.imshow(gray_image.rotate(90))
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## 5. Convert the grayscale image to an RGB image.
# >  Convert the grayscale image into an RGB image where the grayscale values are replicated across all three channels (R, G, and B).
#
#
#
# > Display the converted RGB image using matplotlib.

# %%
# convert the grayscale to an RGB
new_arr = np.stack((gray_image_arr, gray_image_arr,gray_image_arr), axis=-1)
plt.imshow(new_arr)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# # 3. Excercise Three

# %% [markdown]
# ## 1. Load and Prepare Data:

# %%
# Image Compression and Decompression using PCA.

# • Fetch an image of you choice.{If colour convert to grayscale}
image = Image.open("/content/drive/MyDrive/AI ML/Worksheet 1/cameraman.png")

# convert the image to the numpy array
image_array = np.array(image)

# dimension of the numpy array
width, height = image_array.shape

# reshape the array
data = image_array.reshape(height, width)

# • Center the dataset - Standaridze the Data.
mean = np.mean(data,axis = 0)
centered_data = data - mean

# Calculate the covaraince matrix of the Standaridze data.
cov_matrix = np.cov(centered_data,rowvar=False)
print(cov_matrix)
# Out:
# [[543.51861775 520.97947881 492.56189228 ... 452.37668175 465.56655914
#   469.92323569]
#  [520.97947881 515.55188585 504.98165744 ... 438.16924535 451.13798771
#   455.28722786]
#  [492.56189228 504.98165744 514.61175621 ... 415.396557   428.0037075
#   431.84547762]
#  ...
#  [452.37668175 438.16924535 415.396557   ... 694.40484344 701.46153376
#   705.1383317 ]
#  [465.56655914 451.13798771 428.0037075  ... 701.46153376 724.80795927
#   732.40163283]
#  [469.92323569 455.28722786 431.84547762 ... 705.1383317  732.40163283
#   741.0831091 ]]

# %% [markdown]
# ## 2. Eigen Decomposition and Identifying Principal Components

# %%
# Compute Eigen Values and Eigen Vectors.
eigenvalues , eigenvectors = np . linalg . eigh ( cov_matrix )

# Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:,sorted_indices]

# Identify the Principal Components with the help of cumulative Sum plot.
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt.plot( np . cumsum ( explained_variance_ratio ) )
plt.title(" Cumulative Explained Variance ")
plt.xlabel(" Number of Components ")
plt.ylabel(" Cumulative Explained Variance ")
plt.grid( True )
plt.show()

# %% [markdown]
# ## 3. Reconstruction and Experiment:

# %%
# Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
# tors(PCs) to obtain a lower-dimensional representation.
k = 50
components = eigenvectors[:,:k]

# %%
# Project the data onto the principal components
compressed_data = np.dot(centered_data, components)

# %%
# Reconstruct the image from compressed data
decompressed_data = np.dot(compressed_data, components.T ) + mean

# %%
plt . figure ( figsize =(12 , 6) )

# Original Image
plt.subplot(1,3,1)
plt.imshow(image,cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Compressed Representation
plt.subplot(1 , 3 , 2)
plt.imshow(compressed_data ,cmap="gray", aspect="auto")
plt.title( f"Compressed Image (k={k})")
plt.axis("off")

# Decompressed Image
plt.subplot(1 , 3 , 3)
plt.imshow(decompressed_data , cmap ="gray")
plt.title("Decompressed Image")
plt.axis("off")
plt.tight_layout()
plt.show()
